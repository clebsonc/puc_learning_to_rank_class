# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from linear_regresion.linear_regression import LinearRegressionLeastSquare, LinearRegressionGradient
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
x = np.asarray([1, 1.5, 2, 3, 4, 4.5, 5, 6, 7, 8, 9, 10])
y = np.asarray([1.5, 2, 3.5, 4, 3, 4.5, 3, 3.5, 6, 9, 5.5, 6])

# %%
ln = LinearRegressionLeastSquare(x=x, y=y)

# %%
ln.draw()

# %%
ln.solve_equation()

# %%
ln.draw()

# %%
print(ln.m, ln.b)
# Out:
# 0.5487596236099229 1.5021385799828924

# %%
ln2 = LinearRegressionGradient(x=x, y=y, steps=100, learning_rate=0.01)

# %%
ln2.draw()

# %%
a = ln2.train()

# %%
print(ln2.m, ln2.b)
# Out:
# 0.41029218923269517 1.891971036393568

# %%
ln2.draw()
